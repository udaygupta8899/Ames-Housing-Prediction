# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
dataset=pd.read_csv('AmesHousing.csv')

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
df['Alley'].isnull().sum(),df['Misc Feature'].isnull().sum()
# Out:
# (2732, 2824)

# %%
df.drop(['Alley','Misc Feature'],axis=1,inplace=True)

# %%
df
# Out:
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
# ...

# %%
for column in df.columns:
    tot=df[column].isnull().sum()
    if tot>0:
        print(column+":",tot)
# Out:
# Lot Frontage: 490
# Mas Vnr Type: 1775
# Mas Vnr Area: 23
# Bsmt Qual: 80
# Bsmt Cond: 80
# Bsmt Exposure: 83
# BsmtFin Type 1: 80
# BsmtFin SF 1: 1
# BsmtFin Type 2: 81
# BsmtFin SF 2: 1
# Bsmt Unf SF: 1
# Total Bsmt SF: 1
# Electrical: 1
# Bsmt Full Bath: 2
# Bsmt Half Bath: 2
# Fireplace Qu: 1422
# Garage Type: 157
# Garage Yr Blt: 159
# Garage Finish: 159
# Garage Cars: 1
# Garage Area: 1
# Garage Qual: 159
# Garage Cond: 159
# Pool QC: 2917
# Fence: 2358

# %%
df.drop(['Order','PID','Mas Vnr Type','Fireplace Qu','Pool QC','Fence'],axis=1,inplace=True)

# %%
df
# Out:
#       MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0              20        RL         141.0     31770   Pave       IR1
# 1              20        RH          80.0     11622   Pave       Reg
# 2              20        RL          81.0     14267   Pave       IR1
# 3              20        RL          93.0     11160   Pave       Reg
# 4              60        RL          74.0     13830   Pave       IR1
# ...           ...       ...           ...       ...    ...       ...
# 2925           80        RL          37.0      7937   Pave       IR1
# 2926           20        RL           NaN      8885   Pave       IR1
# 2927           85        RL          62.0     10441   Pave       Reg
# 2928           20        RL          77.0     10010   Pave       Reg
# 2929           60        RL          74.0      9627   Pave       Reg
#
#      Land Contour Utilities Lot Config Land Slope  ... Enclosed Porch  \
# ...

# %%
for column in df.columns:
    tot=df[column].isnull().sum()
    if tot>0:
        print(column+":",tot)
# Out:
# Lot Frontage: 490
# Mas Vnr Area: 23
# Bsmt Qual: 80
# Bsmt Cond: 80
# Bsmt Exposure: 83
# BsmtFin Type 1: 80
# BsmtFin SF 1: 1
# BsmtFin Type 2: 81
# BsmtFin SF 2: 1
# Bsmt Unf SF: 1
# Total Bsmt SF: 1
# Electrical: 1
# Bsmt Full Bath: 2
# Bsmt Half Bath: 2
# Garage Type: 157
# Garage Yr Blt: 159
# Garage Finish: 159
# Garage Cars: 1
# Garage Area: 1
# Garage Qual: 159
# Garage Cond: 159

# %%
##Numerical And Categorical Features
num_features=[]
cat_features=[]
for column in df.columns:
    if df[column].dtype!='O':
        num_features.append(column)
    else:
        cat_features.append(column)

# %%
df[num_features].head()
# Out:
#    MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0           20         141.0     31770             6             5
# 1           20          80.0     11622             5             6
# 2           20          81.0     14267             6             6
# 3           20          93.0     11160             7             5
# 4           60          74.0     13830             5             5
#
#    Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  ...  \
# 0        1960            1960         112.0         639.0           0.0  ...
# 1        1961            1961           0.0         468.0         144.0  ...
# 2        1958            1958         108.0         923.0           0.0  ...
# 3        1968            1968           0.0        1065.0           0.0  ...
# 4        1997            1998           0.0         791.0           0.0  ...
#
#    Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  \
# ...

# %%
df[cat_features].head()
# Out:
#   MS Zoning Street Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0        RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 1        RH   Pave       Reg          Lvl    AllPub     Inside        Gtl
# 2        RL   Pave       IR1          Lvl    AllPub     Corner        Gtl
# 3        RL   Pave       Reg          Lvl    AllPub     Corner        Gtl
# 4        RL   Pave       IR1          Lvl    AllPub     Inside        Gtl
#
#   Neighborhood Condition 1 Condition 2  ... Electrical Kitchen Qual  \
# 0        NAmes        Norm        Norm  ...      SBrkr           TA
# 1        NAmes       Feedr        Norm  ...      SBrkr           TA
# 2        NAmes        Norm        Norm  ...      SBrkr           Gd
# 3        NAmes        Norm        Norm  ...      SBrkr           Ex
# 4      Gilbert        Norm        Norm  ...      SBrkr           TA
#
#   Functional Garage Type Garage Finish Garage Qual Garage Cond Paved Drive  \
# ...

# %%
df['Garage Type'].unique()
# Out:
# array(['Attchd', 'BuiltIn', 'Basment', 'Detchd', nan, 'CarPort', '2Types'],
#       dtype=object)

# %%
new_df=df[num_features]

# %%
new_df
# Out:
#       MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0              20         141.0     31770             6             5
# 1              20          80.0     11622             5             6
# 2              20          81.0     14267             6             6
# 3              20          93.0     11160             7             5
# 4              60          74.0     13830             5             5
# ...           ...           ...       ...           ...           ...
# 2925           80          37.0      7937             6             6
# 2926           20           NaN      8885             5             5
# 2927           85          62.0     10441             5             5
# 2928           20          77.0     10010             5             5
# 2929           60          74.0      9627             7             5
#
#       Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# ...

# %%
cols=[]
for column in num_features:
    tot=new_df[column].isnull().sum()
    if(tot>0):
        median_value=np.median(new_df[column].dropna())
        new_df[column].fillna(median_value,inplace=True)

# %%
cols
# Out:
# []

# %%
new_df
# Out:
#       MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0              20         141.0     31770             6             5
# 1              20          80.0     11622             5             6
# 2              20          81.0     14267             6             6
# 3              20          93.0     11160             7             5
# 4              60          74.0     13830             5             5
# ...           ...           ...       ...           ...           ...
# 2925           80          37.0      7937             6             6
# 2926           20          68.0      8885             5             5
# 2927           85          62.0     10441             5             5
# 2928           20          77.0     10010             5             5
# 2929           60          74.0      9627             7             5
#
#       Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# ...

# %%
new_df.isnull().sum()
# Out:
# MS SubClass        0
# Lot Frontage       0
# Lot Area           0
# Overall Qual       0
# Overall Cond       0
# Year Built         0
# Year Remod/Add     0
# Mas Vnr Area       0
# BsmtFin SF 1       0
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# 1st Flr SF         0
# 2nd Flr SF         0
# Low Qual Fin SF    0
# Gr Liv Area        0
# Bsmt Full Bath     0
# Bsmt Half Bath     0
# Full Bath          0
# Half Bath          0
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# TotRms AbvGrd      0
# Fireplaces         0
# Garage Yr Blt      0
# Garage Cars        0
# Garage Area        0
# Wood Deck SF       0
# Open Porch SF      0
# Enclosed Porch     0
# 3Ssn Porch         0
# Screen Porch       0
# Pool Area          0
# Misc Val           0
# Mo Sold            0
# Yr Sold            0
# SalePrice          0
# dtype: int64

# %%
new_df
# Out:
#       MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 0              20         141.0     31770             6             5
# 1              20          80.0     11622             5             6
# 2              20          81.0     14267             6             6
# 3              20          93.0     11160             7             5
# 4              60          74.0     13830             5             5
# ...           ...           ...       ...           ...           ...
# 2925           80          37.0      7937             6             6
# 2926           20          68.0      8885             5             5
# 2927           85          62.0     10441             5             5
# 2928           20          77.0     10010             5             5
# 2929           60          74.0      9627             7             5
#
#       Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# ...

# %%
X=new_df.iloc[:,:-1]
y=new_df['SalePrice']

# %%
##Splitting into training and testing dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#       MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 844            20          68.0      9017             7             5
# 2730          150          68.0      1700             7             5
# 2793           20          68.0     14781             8             5
# 1187           20          85.0     11050             6             5
# 2770           60          65.0     12438             6             5
# ...           ...           ...       ...           ...           ...
# 1638          190         195.0     41600             5             5
# 1095           60          68.0      7750             7             5
# 1130           60          64.0      8791             6             5
# 1294           50          81.0      7308             5             5
# 860            85          60.0      7200             5             8
#
#       Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# ...

# %%
X_test
# Out:
#       MS SubClass  Lot Frontage  Lot Area  Overall Qual  Overall Cond  \
# 1357           70          68.0      5100             8             7
# 2367          160          21.0      1890             6             7
# 2822           60          62.0      7162             7             5
# 2126           20          60.0      8070             4             5
# 1544           30          50.0      7000             6             8
# ...           ...           ...       ...           ...           ...
# 2521          120          40.0      3876             8             5
# 707            30          62.0      7404             4             6
# 424            20         108.0     13173             9             5
# 69             20          75.0      9000             8             5
# 736            50          50.0      6000             6             6
#
#       Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# ...

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,r2_score

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
models={"Linear Regression":LinearRegression(),
        "Lasso":Lasso(),
        "Ridge":Ridge(),
        "ElasticNet":ElasticNet(),
        "SVR":SVR(),
        "KNeighborsRegressor":KNeighborsRegressor()}

# %%
for name,model in models.items():
    try:
        model.fit(X_train_scaled,y_train)
        y_pred=model.predict(X_test_scaled)
        mean_abs_error=mean_absolute_error(y_pred,y_test)
        r2Score=r2_score(y_pred,y_test)
        print(name,":")
        print("Mean Absolute Error: ",mean_abs_error)
        print("R2 Score: ",r2Score)
        print("---------------------------")
    except Exception as e:
        print(f"Model {name} failed with error: {str(e)}")
# Out:
# Linear Regression :
# Mean Absolute Error:  21283.13816550069
# R2 Score:  0.7930063779531881
# ---------------------------
# Lasso :
# Mean Absolute Error:  21282.307349680137
# R2 Score:  0.7929638477603765
# ---------------------------
# Ridge :
# Mean Absolute Error:  21280.226165800697
# R2 Score:  0.7929558429951503
# ---------------------------
# ElasticNet :
# Mean Absolute Error:  21147.338093534083
# R2 Score:  0.7301318411345379
# ---------------------------
# SVR :
# Mean Absolute Error:  60803.37821581969
# R2 Score:  -535757.2175159502
# ---------------------------
# KNeighborsRegressor :
# Mean Absolute Error:  20836.21255115962
# R2 Score:  0.7912369081553667
# ---------------------------

# %% [markdown]
# Let's select the KNeighborsRegressor and apply hyperparameter tuning in it

# %%
from sklearn.model_selection import GridSearchCV
parameters={"n_neighbors":[3,5,7,9,11],
            "weights":['uniform','distance'],
            "metric":['minkowski','euclidean','manhattan']}
estimator=KNeighborsRegressor()
grid_search=GridSearchCV(estimator,parameters, cv=5, scoring='r2', n_jobs=-1, verbose=2)

# %%
grid_search.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(), n_jobs=-1,
#              param_grid={'metric': ['minkowski', 'euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']},
#              scoring='r2', verbose=2)

# %%
print(f"Best params found:{grid_search.best_params_}")
print(f"Best R2 score:{grid_search.best_score_}")
# Out:
# Best params found:{'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# Best R2 score:0.8393065041113263

# %%
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")
print(f"R2 Score: {r2}")
# Out:
# Mean Absolute Error: 20836.21255115962
# R2 Score: 0.8457855738112534
